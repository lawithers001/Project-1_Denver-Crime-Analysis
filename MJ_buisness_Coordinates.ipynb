# %%
import pandas as pd
import numpy as np
import calendar
from time import strptime
from datetime import datetime
from matplotlib import pyplot as plt

# %%
import gmaps
gmaps.configure(api_key="AIzaSyDHJPmivG-THCD7di354x3gQm9Vj_zBvz8")

# %%
df_mj_buisnesses= pd.read_csv("csv files\\marijuana_active_business_licenses.csv")

# %%
df_mj_buisnesses['Clean_adress'] = df_mj_buisnesses['Facility Street Number'].astype(str)[:-2] + " "+ df_mj_buisnesses['Facility Street Name'] +" "+ df_mj_buisnesses['Facility Street Type']
df_mj_buisnesses['geocode']=df_mj_buisnesses['Facility Street Number']
df_short=df_mj_buisnesses.head(5)
df_short
# Out:
#   Business File Number                    License Type  \
# 0     2015-BFN-0003448    Med Marijuana Inf Prod Manuf
# 1     2015-BFN-0003449   Med Marijuana Opt Prem Cultiv
# 2     2015-BFN-0003648   Med Marijuana Opt Prem Cultiv
# 3     2015-BFN-0004345  Retail Marij Opt. Prem. Cultiv
# 4     2015-BFN-0004100        Medical Marijuana Center
#
#                Entity Name                             Trade Name  \
# 0  DARK HORSE GENETICS LLC                                    NaN
# 1  DARK HORSE GENETICS LLC                                    NaN
# 2          SUMMIT WELLNESS  DEN-REC DENVER RECRATIONAL DISPENSARY
# 3             M.J.L. Q LLC                             WHOLE MEDS
# 4     TRILL EVOLUTIONS LLC                       TRILL EVOLUTIONS
#
#     Current License Status         Expiration Date  Facility Street Number  \
# 0  License Issued - Active   9/14/2018 12:00:00 AM                  2145.0
# 1  License Issued - Active   9/14/2018 12:00:00 AM                  2145.0
# ...

# %%
def get_lat_long(clean_address): 
    from geopy.geocoders import GoogleV3
    geolocator = GoogleV3(format_string="%s, Denver CO")
    address, (latitude, longitude) = geolocator.geocode(clean_address)
    print((address, latitude, longitude))
    return((address, latitude, longitude))

df_short['geocode']=df_short['Clean_adress'].map(get_lat_long)
# Out:
# ('2145 S Kalamath St, Denver, CO 80223, USA', 39.677619, -105.000938)
# ('2145 S Kalamath St, Denver, CO 80223, USA', 39.677619, -105.000938)
# ('Bannock St, Denver, CO, USA', 39.7281487, -104.9901873)
# ('E 39th Ave, Denver, CO, USA', 39.7714163, -104.9289971)
# ('Joliet St, Colorado, USA', 39.756862, -104.8611766)
# C:\Users\lawit\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
df_short
# Out:
#   Business File Number                    License Type  \
# 0     2015-BFN-0003448    Med Marijuana Inf Prod Manuf
# 1     2015-BFN-0003449   Med Marijuana Opt Prem Cultiv
# 2     2015-BFN-0003648   Med Marijuana Opt Prem Cultiv
# 3     2015-BFN-0004345  Retail Marij Opt. Prem. Cultiv
# 4     2015-BFN-0004100        Medical Marijuana Center
#
#                Entity Name                             Trade Name  \
# 0  DARK HORSE GENETICS LLC                                    NaN
# 1  DARK HORSE GENETICS LLC                                    NaN
# 2          SUMMIT WELLNESS  DEN-REC DENVER RECRATIONAL DISPENSARY
# 3             M.J.L. Q LLC                             WHOLE MEDS
# 4     TRILL EVOLUTIONS LLC                       TRILL EVOLUTIONS
#
#     Current License Status         Expiration Date  Facility Street Number  \
# 0  License Issued - Active   9/14/2018 12:00:00 AM                  2145.0
# 1  License Issued - Active   9/14/2018 12:00:00 AM                  2145.0
# ...

# %%
df_short['lat']=df_short['geocode'].apply(lambda x: x[1])
df_short['long']=df_short['geocode'].apply(lambda x: x[2])
df_short
# Out:
# C:\Users\lawit\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\lawit\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   Business File Number                    License Type  \
# 0     2015-BFN-0003448    Med Marijuana Inf Prod Manuf
# 1     2015-BFN-0003449   Med Marijuana Opt Prem Cultiv
# 2     2015-BFN-0003648   Med Marijuana Opt Prem Cultiv
# ...

# %%
### Running Lat and Long on full Dataframe 
df_mj_buisnesses['geocode']=df_mj_buisnesses['Clean_adress'].map(get_lat_long) 
df_mj_buisnesses['lat']=df_mj_buisnesses['geocode'].apply(lambda x: x[1])
df_mj_buisnesses['long']=df_mj_buisnesses['geocode'].apply(lambda x: x[2])
df_mj_buisnesses
# Out:
# ('2145 S Kalamath St, Denver, CO 80223, USA', 39.677619, -105.000938)
# ('2145 S Kalamath St, Denver, CO 80223, USA', 39.677619, -105.000938)
# ('Bannock St, Denver, CO, USA', 39.7281487, -104.9901873)
# ('E 39th Ave, Denver, CO, USA', 39.7714163, -104.9289971)
# ('Joliet St, Colorado, USA', 39.756862, -104.8611766)
# ('7700 E Arapahoe Rd #275, Centennial, CO 80112, USA', 39.5942614, -104.8993526)
# ('1900 Grant St # 1250, Denver, CO 80203, USA', 39.7465077, -104.9831529)
# ('Grape St, Denver, CO, USA', 39.7734782, -104.9246086)
# ('S Huron St, Denver, CO, USA', 39.6585791, -104.9969945)
# ('Denver, CO, USA', 39.7392358, -104.990251)
# ('Dahlia St, Denver, CO, USA', 39.7856014, -104.9316316)
# ('Oakland St, Aurora, CO, USA', 39.7531734, -104.8505276)
# ('Ivy St, Denver, CO, USA', 39.7805202, -104.9200304)
# ('5475 Peoria St #4-106, Denver, CO 80239, USA', 39.79502859999999, -104.8487144)
# ('Mariposa St, Denver, CO, USA', 39.7294877, -105.0028381)
# ...

# %%
df_categories=df_mj_buisnesses.groupby('License Type').count().reset_index()
df_categories
# Out:
#                      License Type  Business File Number  Entity Name  \
# 0           Marijuana Transporter                     2            2
# 1    Med Marijuana Inf Prod Manuf                    94           94
# 2   Med Marijuana Opt Prem Cultiv                   361          361
# 3     Med Marijuana Test Facility                     5            5
# 4        Medical Marijuana Center                   196          196
# 5  Retail Marij Opt. Prem. Cultiv                   215          215
# 6   Retail Marijuana Inf Prod Mfg                    86           86
# 7          Retail Marijuana Store                   166          166
# 8  Retail Marijuana Test Facility                     5            5
#
#    Trade Name  Current License Status  Expiration Date  \
# 0           2                       2                2
# 1          60                      94               94
# 2         287                     361              361
# ...

# %%
def filter_mj_type(License_type):
    if 'Medical Marijuana Center' in License_type:
        return "Store"
    elif 'Retail Marijuana Store' in License_type: 
        return "Store" 
    elif 'Med Marijuana Inf Prod Manuf' in License_type: 
        return "Manufacturer" 
    elif 'Retail Marijuana Inf Prod Mfg' in License_type: 
        return "Manufacturer"
    elif 'Med Marijuana Opt Prem Cultiv' in License_type: 
        return "Cultivation"
    elif 'Retail Marij Opt. Prem. Cultiv' in License_type: 
        return "Cultivation"
    elif 'Retail Marijuana Test Facility' in License_type: 
        return "Testing"
    elif 'Med Marijuana Test Facility' in License_type: 
        return "Testing"
    else:
        return "transporter"

# %%
df_mj_buisnesses['MJ_buisness_Type']=df_mj_buisnesses["License Type"].map(filter_mj_type)

# %%
df_mj_buisnesses
# Out:
#      Business File Number                    License Type  \
# 0        2015-BFN-0003448    Med Marijuana Inf Prod Manuf
# 1        2015-BFN-0003449   Med Marijuana Opt Prem Cultiv
# 2        2015-BFN-0003648   Med Marijuana Opt Prem Cultiv
# 3        2015-BFN-0004345  Retail Marij Opt. Prem. Cultiv
# 4        2015-BFN-0004100        Medical Marijuana Center
# 5        2015-BFN-0004779        Medical Marijuana Center
# 6        2015-BFN-0005338        Medical Marijuana Center
# 7        2015-BFN-0006100   Med Marijuana Opt Prem Cultiv
# 8        2015-BFN-0007620   Med Marijuana Opt Prem Cultiv
# 9        2015-BFN-0007634   Med Marijuana Opt Prem Cultiv
# 10       2015-BFN-0007670   Med Marijuana Opt Prem Cultiv
# 11       2015-BFN-0008318   Med Marijuana Opt Prem Cultiv
# 12       2015-BFN-0008256   Med Marijuana Opt Prem Cultiv
# 13       2015-BFN-0007832    Med Marijuana Inf Prod Manuf
# 14       2015-BFN-0007874   Med Marijuana Opt Prem Cultiv
# ...

# %%
df_dict_prep=df_mj_buisnesses[['Entity Name','geocode']]
df_dict_prep
Full_Dict_Prep=df_dict_prep.T.to_dict()
Full_Dict_Prep
# Out:
# {0: {'Entity Name': 'DARK HORSE GENETICS LLC', 'geocode': 2145.0},
#  1: {'Entity Name': 'DARK HORSE GENETICS LLC', 'geocode': 2145.0},
#  2: {'Entity Name': 'SUMMIT WELLNESS', 'geocode': 1901.0},
#  3: {'Entity Name': 'M.J.L. Q LLC', 'geocode': 5959.0},
#  4: {'Entity Name': 'TRILL EVOLUTIONS LLC', 'geocode': 5550.0},
#  5: {'Entity Name': 'TOP SHELF, LLC', 'geocode': 135.0},
#  6: {'Entity Name': 'MMRD, LLC', 'geocode': 1250.0},
#  7: {'Entity Name': 'GREEN SATIVA LLC', 'geocode': 3990.0},
#  8: {'Entity Name': 'ALLGREENS, LLC', 'geocode': 1235.0},
#  9: {'Entity Name': 'J&P INVESTMENTS, LLC', 'geocode': 3850.0},
#  10: {'Entity Name': 'RJJ SANTA FE, LLC', 'geocode': 4990.0},
#  11: {'Entity Name': 'LBW CONSULTING, GROUP,LLC', 'geocode': 5070.0},
#  12: {'Entity Name': 'AMERICAN INDUSTRY, LLC', 'geocode': 4571.0},
#  13: {'Entity Name': 'WONDERLAND EDIBLES, LTD.', 'geocode': 5475.0},
#  14: {'Entity Name': 'EJB VENTURES, LLC', 'geocode': 121.0},
# ...

# %%
df_categories_2=df_mj_buisnesses.groupby('MJ_buisness_Type').count()
df_categories_2
Full_Dict=df_mj_buisnesses.T.to_dict()
# Out:
#                   Business File Number  License Type  Entity Name  Trade Name  \
# MJ_buisness_Type
# Cultivation                        576           576          576         442
# Manufacturer                       180           180          180         118
# Store                              362           362          362         310
# Testing                             10            10           10           3
# transporter                          2             2            2           2
#
#                   Current License Status  Expiration Date  \
# MJ_buisness_Type
# Cultivation                          576              576
# Manufacturer                         180              180
# Store                                362              362
# Testing                               10               10
# transporter                            2                2
#
#                   Facility Street Number  Facility Pre-Direction  \
# MJ_buisness_Type
# ...

# %%
Stores=[]

def create_dict(buisness_type): 
    if 'Store' in buisness_type: 
        name= 
        
        
    elif 'Retail Marijuana Store' in License_type: 
        return "Store" 
    elif 'Med Marijuana Inf Prod Manuf' in License_type: 
        return "Manufacturer" 
    elif 'Retail Marijuana Inf Prod Mfg' in License_type: 
        return "Manufacturer"
    elif 'Med Marijuana Opt Prem Cultiv' in License_type: 
        return "Cultivation"

# %%
# Out:
#   File "<ipython-input-184-85a1eb8a7e3c>", line 2
#     Test_2 = dict(zip(df_mj_buisnesses.(geocode), df_mj_buisnesses.(Business File Number')))
#                                        ^
# SyntaxError: invalid syntax

# %%
Full_Dict=df_mj_buisnesses.T.to_dict()
Full_Dict[0]
#df_mj_buisnesses.T.to_dict().keys()
# Out:
# {'Business File Number': '2015-BFN-0003448',
#  'Clean_adress': '2145.0 KALAMATH ST',
#  'Current License Status': 'License Issued - Active',
#  'Entity Name': 'DARK HORSE GENETICS LLC',
#  'Expiration Date': '9/14/2018 12:00:00 AM',
#  'Facility City': 'DENVER',
#  'Facility Pre-Direction': 'S',
#  'Facility Street Name': 'KALAMATH',
#  'Facility Street Number': 2145.0,
#  'Facility Street Type': 'ST',
#  'Facility Unit Number': nan,
#  'Facility Zip Code': 80223.0,
#  'License Type': 'Med Marijuana Inf Prod Manuf',
#  'MJ_buisness_Type': 'Manufacturer',
#  'Trade Name': nan,
#  'geocode': 2145.0}

# %%
entity_list = []
geocodes = []
i = 0
while i < len(Full_Dict):
    entity_list.append(Full_Dict[i]['Entity Name'])
    geocodes.append(str((Full_Dict)[i]['Facility Zip Code']))
    i += 1
dicts = []
i = 0
while i < len(entity_list):
    name = "'name'" + ':'
    location = "'location'" + ':'
    ind_dict = name +  "'" + entity_list[i] + "'" + ","  + location + "'" + geocodes[i] + "'"
    dicts.append(ind_dict)
    i +=1

# %%
#Full_Dict=df_mj_buisnesses['Entity Name'].to_dict()
#Full_Dict

# %%
dicts
# Out:
# ["'name':'DARK HORSE GENETICS LLC','location':'80223.0'",
#  "'name':'DARK HORSE GENETICS LLC','location':'80223.0'",
#  "'name':'SUMMIT WELLNESS','location':'80223.0'",
#  "'name':'M.J.L. Q LLC','location':'80207.0'",
#  "'name':'TRILL EVOLUTIONS LLC','location':'80239.0'",
#  "'name':'TOP SHELF, LLC','location':'80209.0'",
#  "'name':'MMRD, LLC','location':'80203.0'",
#  "'name':'GREEN SATIVA LLC','location':'80207.0'",
#  "'name':'ALLGREENS, LLC','location':'80223.0'",
#  "'name':'J&P INVESTMENTS, LLC','location':'80216.0'",
#  "'name':'RJJ SANTA FE, LLC','location':'80216.0'",
#  "'name':'LBW CONSULTING, GROUP,LLC','location':'80239.0'",
#  "'name':'AMERICAN INDUSTRY, LLC','location':'80216.0'",
#  "'name':'WONDERLAND EDIBLES, LTD.','location':'80239.0'",
#  "'name':'EJB VENTURES, LLC','location':'80223.0'",
#  "'name':'EJB VENTURES, LLC','location':'80223.0'",
#  "'name':'RJJ SHERIDAN, LLC','location':'80216.0'",
#  "'name':'I&S, LLC','location':'80204.0'",
# ...

# %%
# Out:
# ['DARK HORSE GENETICS LLC',
#  'DARK HORSE GENETICS LLC',
#  'SUMMIT WELLNESS',
#  'M.J.L. Q LLC',
#  'TRILL EVOLUTIONS LLC',
#  'TOP SHELF, LLC',
#  'MMRD, LLC',
#  'GREEN SATIVA LLC',
#  'ALLGREENS, LLC',
#  'J&P INVESTMENTS, LLC',
#  'RJJ SANTA FE, LLC',
#  'LBW CONSULTING, GROUP,LLC',
#  'AMERICAN INDUSTRY, LLC',
#  'WONDERLAND EDIBLES, LTD.',
#  'EJB VENTURES, LLC',
#  'EJB VENTURES, LLC',
#  'RJJ SHERIDAN, LLC',
#  'I&S, LLC',
#  'Mx, LLC',
#  'KGBI COLORADO LLC',
#  'ELIOT GROUP, LLC',
#  'GOOD LIFE, COLORADO LLC',
#  'BIG TOE LLC',
#  'KIND LOVE, LLC',
#  'URBANE DEVELOPERS LLC',
#  'LUMINESCENCE LABS, INC.',
#  "B'S TREATS LLC",
#  'ECO GREEN GROW, LLC',
#  'KTA LLC',
#  'LBW CONSULTING GROUP LLC',
#  'ANIMAS HERBAL WELLNESS CENTER INC.',
#  'BK HOLDINGS, LLC',
#  'PATIENTS PLUS LLC',
#  'SMART CARE, LLC',
#  'AJS EVANS, LLC',
#  'CANNABIS FOR HEALTH, LLC',
#  'I&S LLC',
#  'CONSCIOUS CONFECTIONS, LLC',
#  'RJJ SHERIDAN, LLC',
#  'RJJ HIGHLANDS, LLC',
# ...

# %%
ok = df_dict_prep['Entity Name'].tolist()
ok1 = df_dict_prep['geocode'].tolist()

ok2 = list(zip(ok,ok1))

# %%
ok2
# Out:
# [('DARK HORSE GENETICS LLC', 2145.0),
#  ('DARK HORSE GENETICS LLC', 2145.0),
#  ('SUMMIT WELLNESS', 1901.0),
#  ('M.J.L. Q LLC', 5959.0),
#  ('TRILL EVOLUTIONS LLC', 5550.0),
#  ('TOP SHELF, LLC', 135.0),
#  ('MMRD, LLC', 1250.0),
#  ('GREEN SATIVA LLC', 3990.0),
#  ('ALLGREENS, LLC', 1235.0),
#  ('J&P INVESTMENTS, LLC', 3850.0),
#  ('RJJ SANTA FE, LLC', 4990.0),
#  ('LBW CONSULTING, GROUP,LLC', 5070.0),
#  ('AMERICAN INDUSTRY, LLC', 4571.0),
#  ('WONDERLAND EDIBLES, LTD.', 5475.0),
#  ('EJB VENTURES, LLC', 121.0),
#  ('EJB VENTURES, LLC', 121.0),
#  ('RJJ SHERIDAN, LLC', 4990.0),
#  ('I&S, LLC', 1235.0),
#  ('Mx, LLC', 3855.0),
#  ('KGBI COLORADO LLC', 400.0),
#  ('ELIOT GROUP, LLC', 5200.0),
#  ('GOOD LIFE, COLORADO LLC', 5475.0),
#  ('BIG TOE LLC', 5353.0),
#  ('KIND LOVE, LLC', 4890.0),
#  ('URBANE DEVELOPERS LLC', 2191.0),
#  ('LUMINESCENCE LABS, INC.', 3925.0),
#  ("B'S TREATS LLC", 1952.0),
#  ('ECO GREEN GROW, LLC', 5000.0),
#  ('KTA LLC', 3944.0),
# ...
